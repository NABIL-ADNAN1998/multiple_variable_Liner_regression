# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df = pd.read_csv('/content/drive/MyDrive/colab_practice_datasets/Car_data.csv')

# %%
df
# Out:
#    speed  car_age  experience  risk
# 0    200       15         5.0    85
# 1     90       17        13.0    20
# 2    165       12         4.0    93
# 3    110       20         NaN    60
# 4    140        5         3.0    82
# 5    115        2         8.0    10

# %%
df['experience']
# Out:
# 0     5.0
# 1    13.0
# 2     4.0
# 3     NaN
# 4     3.0
# 5     8.0
# Name: experience, dtype: float64

# %%
df['experience'].mean()
# Out:
# 6.6

# %%
exp_fit = df['experience'].median()
exp_fit
# Out:
# 5.0

# %%
df['experience']= df['experience'].fillna(exp_fit)

# %%
df['experience']
# Out:
# 0     5.0
# 1    13.0
# 2     4.0
# 3     5.0
# 4     3.0
# 5     8.0
# Name: experience, dtype: float64

# %%
df
# Out:
#    speed  car_age  experience  risk
# 0    200       15         5.0    85
# 1     90       17        13.0    20
# 2    165       12         4.0    93
# 3    110       20         5.0    60
# 4    140        5         3.0    82
# 5    115        2         8.0    10

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop(['risk'],axis=1)
y = df['risk']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3)

# %%
train_data = x_train.join(y_train)

# %%
train_data

# %%
reg = linear_model.LinearRegression()

reg = reg.fit(x_train, y_train)

# %%
ans = reg.predict([[160, 10, 5]])

ans
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([73.20634921])

# %%
reg.coef_
# Out:
# array([ -0.27460317,   4.55555556, -13.03968254])

# %%
reg.intercept_
